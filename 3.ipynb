# %% [markdown]
# Aim : Implement POS Tagging

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Natural Language Processing is amazing, and I love learning about it."

doc = nlp(text)

print(f"{'Word':<15} {'POS Tag':<10}")
for token in doc:
    print(f"{token.text:<15} {token.pos_:<10}")
# Out:
# Word            POS Tag
# Natural         PROPN
# Language        PROPN
# Processing      PROPN
# is              AUX
# amazing         ADJ
# ,               PUNCT
# and             CCONJ
# I               PRON
# love            VERB
# learning        VERB
# about           ADP
# it              PRON
# .               PUNCT
